# %% [markdown]
# #ML - Logistics Regression
#
#                                  SUBMITTED BY: MD FAHAM NAUSHAD

# %% [markdown]
# #***************************************************
# ##QuestionS:
#
# #***************************************************
#
# 1. What is Simple Linear Regression (SLR)? Explain its purpose.
#
# - Answer:
#
#     Simple Linear Regression (SLR) is a statistical and machine-learning technique used to model the relationship between one independent variable (X) and one dependent variable (Y) by fitting a straight line.
#
#     - The purpose of SLR is:
#
#       - To predict the value of Y based on X.
#
#       - To understand how X influences Y.
#
#       - To determine whether the relationship is positive, negative, or no relationship.
#
#       - To quantify the strength of the relationship.
#
#     The regression line is also called the line of best fit because it minimizes prediction errors.
#
#   #Example – Python Code:
#
#     - Fit a simple linear regression model and print slope & intercept

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
Y = np.array([2, 4, 5, 4, 5])

# Create and train model
model = LinearRegression()
model.fit(X, Y)

# Print slope and intercept
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope: 0.6
# Intercept: 2.2

# %% [markdown]
# ##2. What are the key assumptions of Simple Linear Regression?
# - Answer:
#
#     - Simple Linear Regression relies on several important assumptions:
#
#       - Linearity – The relationship between X and Y must be a straight line.
#
#       - Independence – Data points should be independent of each other.
#
#       - Homoscedasticity – Variance of residuals should remain constant across X values.
#
#       - Normality of errors – Residuals follow a roughly normal distribution.
#
#       - No major outliers – Extreme values can distort the model.
#
# ##3. Write the mathematical equation for a simple linear regression model and explain each term.
# - Answer:
#
#     The SLR equation is:
#
#                     𝑌 = β₀ + β₁𝑋 + 𝜀
#
#       Where:
#
#           Y → Predicted output
#
#           X → Input/independent variable
#
#           β₀ (Intercept) → Value of Y when X = 0
#
#           β₁ (Slope) → Change in Y for one-unit change in X
#
#           ε (Error term) → Difference between actual and predicted values
#
#       This equation represents the best-fit line that explains the relationship between X and Y.
#
# ##4. Provide a real-world example where simple linear regression can be applied.
# - Answer:
#
#     A common real-world example is predicting house price based on area.
#     If you collect data of home sizes (in sq. ft.) and their prices, SLR can help estimate how much the price increases per additional square foot.
#     The regression line shows the general pricing trend and helps make price predictions for new houses.
#
# ##5. What is the method of least squares in linear regression?
# - Answer:
#
#     The least squares method finds the best-fit line by minimizing the sum of squared residuals.
#
#     A residual is the difference between the actual value (Y) and predicted value (Ŷ).
#     By squaring and summing these errors, the method ensures that the line chosen gives the lowest possible error, producing the most accurate prediction line.
#
# ##6. What is Logistic Regression? How does it differ from Linear Regression?
# - Answer:
#
#     Logistic Regression is a classification method used when the output variable is categorical (e.g., Yes/No, 0/1).
#     It predicts probabilities using a sigmoid (S-shaped) function.
#
#     - Difference:
#
#       - Linear Regression → predicts continuous values (e.g., price, temperature).
#
#       - Logistic Regression → predicts class probabilities (e.g., spam or not spam).
#
#       - Logistic uses a sigmoid function, while linear uses a straight line.
#
# ##7. Name and briefly describe three common evaluation metrics for regression models.
# - Answer:
#
#     - Mean Absolute Error (MAE) – Average of absolute differences between actual and predicted values.
#
#     - Mean Squared Error (MSE) – Average of squared prediction errors; penalizes large errors.
#
#    -  R-squared (R²) – Measures how much variation in Y is explained by the model (0 to 1 scale).
#
# ##8. What is the purpose of the R-squared metric in regression analysis?
# - Answer:
#
#     R-squared measures how well the regression model explains the variation in the dependent variable.
#
#     It ranges from 0 to 1, where higher values indicate a better fit.
#
#     For example, R² = 0.85 means the model explains 85% of the variation in the data.
#
#     It helps determine whether the model is useful and how well it captures the relationship.
#
# ##9. Write Python code to fit a simple linear regression model using scikit-learn and print the slope and intercept. (Include your Python code and output.)**
#
# - Answer
#
#     ✅Python Code:

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Sample data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
Y = np.array([3, 4, 2, 5, 6])

# Create model
model = LinearRegression()
model.fit(X, Y)

# Print slope and intercept
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope: 0.6999999999999998
# Intercept: 1.9000000000000004

# %% [markdown]
# ##10. How do you interpret the coefficients in a simple linear regression model?
# - Answer:
#
#     - In SLR:
#
#       - Slope (β₁): Shows how much Y changes for every 1-unit increase in X.
#
#         Example: If slope = 2, then Y increases by 2 for each increase of 1 in X.
#
#       - Intercept (β₀): The predicted value of Y when X = 0.
#
#         Together, these coefficients describe how strongly and in what direction X influences Y.

# %% [markdown]
# #************************************ END ************************************
